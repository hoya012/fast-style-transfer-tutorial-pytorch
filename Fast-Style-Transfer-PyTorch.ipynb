# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
from PIL import Image
from IPython.display import display 
import matplotlib.pyplot as plt
from torchvision import datasets
import torchvision.transforms as transforms
import torchvision.models as models
import torchsummary
import numpy as np
from collections import namedtuple

import copy
import time
import glob
import re
import cv2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Download COCO Dataset - http://images.cocodataset.org/zips/val2017.zip
#
# some differences:
#
# Original paper: COCO 2014 train --> 80000 images & 13GB
#
# My implementation: COCO 2017 val --> 5000 images / 1GB --> x16 epochs

# %%
style_image_location = "/content/gdrive/My Drive/Colab_Notebooks/data/vikendi.jpg" #FIXME

style_image_sample = Image.open(style_image_location, 'r')
display(style_image_sample)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F0095165588>

# %%
batch_size = 8
random_seed = 10
num_epochs = 64 
initial_lr = 1e-3
checkpoint_dir = "/content/gdrive/My Drive/Colab_Notebooks/data/" #FIXME

content_weight = 1e5
style_weight = 1e10
log_interval = 50
checkpoint_interval = 500

#running_option = "test" #FIXME 
running_option = "test_video" #FIXME
#running_option = "training" #FIXME

# %%
class VGG16(torch.nn.Module):
    def __init__(self, requires_grad=False):
        super(VGG16, self).__init__()
        vgg_pretrained_features = models.vgg16(pretrained=True).features
        self.slice1 = torch.nn.Sequential()
        self.slice2 = torch.nn.Sequential()
        self.slice3 = torch.nn.Sequential()
        self.slice4 = torch.nn.Sequential()
        for x in range(4):
            self.slice1.add_module(str(x), vgg_pretrained_features[x])
        for x in range(4, 9):
            self.slice2.add_module(str(x), vgg_pretrained_features[x])
        for x in range(9, 16):
            self.slice3.add_module(str(x), vgg_pretrained_features[x])
        for x in range(16, 23):
            self.slice4.add_module(str(x), vgg_pretrained_features[x])
        if not requires_grad:
            for param in self.parameters():
                param.requires_grad = False

    def forward(self, X):
        h = self.slice1(X)
        h_relu1_2 = h
        h = self.slice2(h)
        h_relu2_2 = h
        h = self.slice3(h)
        h_relu3_3 = h
        h = self.slice4(h)
        h_relu4_3 = h
        vgg_outputs = namedtuple("VggOutputs", ['relu1_2', 'relu2_2', 'relu3_3', 'relu4_3'])
        out = vgg_outputs(h_relu1_2, h_relu2_2, h_relu3_3, h_relu4_3)
        return out

# %%
class ConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super(ConvLayer, self).__init__()
        reflection_padding = kernel_size // 2
        self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        out = self.reflection_pad(x)
        out = self.conv2d(out)
        return out

# %%
class ResidualBlock(nn.Module):
    """ResidualBlock
    introduced in: https://arxiv.org/abs/1512.03385
    recommended architecture: http://torch.ch/blog/2016/02/04/resnets.html
    """

    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = ConvLayer(channels, channels, kernel_size=3, stride=1)
        self.in1 = nn.InstanceNorm2d(channels, affine=True)
        self.conv2 = ConvLayer(channels, channels, kernel_size=3, stride=1)
        self.in2 = nn.InstanceNorm2d(channels, affine=True)
        self.relu = nn.ReLU()

    def forward(self, x):
        residual = x
        out = self.relu(self.in1(self.conv1(x)))
        out = self.in2(self.conv2(out))
        out = out + residual
        return out

# %%
class UpsampleConvLayer(nn.Module):
    """UpsampleConvLayer
    Upsamples the input and then does a convolution. This method gives better results
    compared to ConvTranspose2d.
    ref: http://distill.pub/2016/deconv-checkerboard/
    """

    def __init__(self, in_channels, out_channels, kernel_size, stride, upsample=None):
        super(UpsampleConvLayer, self).__init__()
        self.upsample = upsample
        reflection_padding = kernel_size // 2
        self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        x_in = x
        if self.upsample:
            x_in = nn.functional.interpolate(x_in, mode='nearest', scale_factor=self.upsample)
        out = self.reflection_pad(x_in)
        out = self.conv2d(out)
        return out

# %%
class TransformerNet(nn.Module):
    def __init__(self):
        super(TransformerNet, self).__init__()
        # Initial convolution layers
        self.encoder = nn.Sequential()
        
        self.encoder.add_module('conv1', ConvLayer(3, 32, kernel_size=9, stride=1))
        self.encoder.add_module('in1', nn.InstanceNorm2d(32, affine=True))
        self.encoder.add_module('relu1', nn.ReLU())
        
        self.encoder.add_module('conv2', ConvLayer(32, 64, kernel_size=3, stride=2))
        self.encoder.add_module('in2', nn.InstanceNorm2d(64, affine=True))
        self.encoder.add_module('relu2', nn.ReLU())
        
        self.encoder.add_module('conv3', ConvLayer(64, 128, kernel_size=3, stride=2))
        self.encoder.add_module('in3', nn.InstanceNorm2d(128, affine=True))
        self.encoder.add_module('relu3', nn.ReLU())

        # Residual layers
        self.residual = nn.Sequential()
        
        for i in range(5):
          self.residual.add_module('resblock_%d' %(i+1), ResidualBlock(128))
        
        # Upsampling Layers
        self.decoder = nn.Sequential()
        self.decoder.add_module('deconv1', UpsampleConvLayer(128, 64, kernel_size=3, stride=1, upsample=2))
        self.decoder.add_module('in4', nn.InstanceNorm2d(64, affine=True))
        self.encoder.add_module('relu4', nn.ReLU())

        self.decoder.add_module('deconv2', UpsampleConvLayer(64, 32, kernel_size=3, stride=1, upsample=2))
        self.decoder.add_module('in5', nn.InstanceNorm2d(32, affine=True))
        self.encoder.add_module('relu5', nn.ReLU())

        self.decoder.add_module('deconv3', ConvLayer(32, 3, kernel_size=9, stride=1))


    def forward(self, x):
        encoder_output = self.encoder(x)
        residual_output = self.residual(encoder_output)
        decoder_output = self.decoder(residual_output)
        
        return decoder_output

# %%
# Video Capture Sanity Check
cap = cv2.VideoCapture("/content/gdrive/My Drive/Colab_Notebooks/data/mirama_demo.mp4")

while(cap.isOpened()):
    ret, frame = cap.read()
    frame = frame[:,:,::-1]
    
    print(frame.shape)
    
    plt.imshow(frame)
    
    break
cap.release()
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)

# %%
""" Util Functions """
def load_image(filename, size=None, scale=None):
    img = Image.open(filename)
    if size is not None:
        img = img.resize((size, size), Image.ANTIALIAS)
    elif scale is not None:
        img = img.resize((int(img.size[0] / scale), int(img.size[1] / scale)), Image.ANTIALIAS)
    return img
    

def save_image(filename, data):
    img = data.clone().clamp(0, 255).numpy()
    img = img.transpose(1, 2, 0).astype("uint8")
    img = Image.fromarray(img)
    display(img)
    img.save(filename)

def post_process_image(data):
    img = data.clone().clamp(0, 255).numpy()
    img = img.transpose(1, 2, 0).astype("uint8")
    #img = Image.fromarray(img)
    
    return img
    

def gram_matrix(y):
    (b, ch, h, w) = y.size()
    features = y.view(b, ch, w * h)
    features_t = features.transpose(1, 2)
    gram = features.bmm(features_t) / (ch * h * w)
    return gram


def normalize_batch(batch):
    # normalize using imagenet mean and std
    mean = batch.new_tensor([0.485, 0.456, 0.406]).view(-1, 1, 1)
    std = batch.new_tensor([0.229, 0.224, 0.225]).view(-1, 1, 1)
    batch = batch.div_(255.0)
    return (batch - mean) / std

# %%
np.random.seed(random_seed)
torch.manual_seed(random_seed)

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.mul(255))
])

style_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.mul(255))
])

print(glob.glob("/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/*"))

train_dataset = datasets.ImageFolder("/content/gdrive/My Drive/Colab_Notebooks/data/COCO", transform) #FIXME
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
# Out:
# ['/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000089761.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000404249.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000323709.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000085772.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000126110.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000151051.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000376856.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000218439.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000500565.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000419653.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000342295.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000554266.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000498709.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000464089.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000096825.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000015440.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000507575.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000343466.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000210388.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000239773.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000289586.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000565624.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000180188.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000363784.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000536038.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000109313.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000091500.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000128658.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000128112.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000443969.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000224675.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000111609.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000234413.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000028449.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000445675.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000015746.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000098392.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000512403.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000294350.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000296222.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000474095.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000564133.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000257624.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000328601.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000485237.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000296231.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000435880.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000355169.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000321887.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/COCO/val2017/000000155291.jpg', '/content/gdrive/My Drive/Colab_Notebooks/data/CO ...

# %%
transformer = TransformerNet()
vgg = VGG16(requires_grad=False).to(device)

# %%
optimizer = torch.optim.Adam(transformer.parameters(), initial_lr)
mse_loss = nn.MSELoss()

style = load_image(filename=style_image_location, size=None, scale=None)
style = style_transform(style)
style = style.repeat(batch_size, 1, 1, 1).to(device)

features_style = vgg(normalize_batch(style))
gram_style = [gram_matrix(y) for y in features_style]

# %%
transfer_learning = False # inference or training first --> False / Transfer learning --> True
ckpt_model_path = os.path.join(checkpoint_dir, "ckpt_epoch_63_batch_id_500.pth") #FIXME

if transfer_learning:
  checkpoint = torch.load(ckpt_model_path, map_location=device)
  transformer.load_state_dict(checkpoint['model_state_dict'])
  transformer.to(device)

# %%
if running_option == "training":
  if transfer_learning:
      transfer_learning_epoch = checkpoint['epoch'] 
  else:
      transfer_learning_epoch = 0

  for epoch in range(transfer_learning_epoch, num_epochs):
        transformer.train()
        agg_content_loss = 0.
        agg_style_loss = 0.
        count = 0

        for batch_id, (x, _) in enumerate(train_loader):
            n_batch = len(x)
            count += n_batch
            optimizer.zero_grad()

            x = x.to(device)
            y = transformer(x)

            y = normalize_batch(y)
            x = normalize_batch(x)

            features_y = vgg(y)
            features_x = vgg(x)

            content_loss = content_weight * mse_loss(features_y.relu2_2, features_x.relu2_2)

            style_loss = 0.
            for ft_y, gm_s in zip(features_y, gram_style):
                gm_y = gram_matrix(ft_y)
                style_loss += mse_loss(gm_y, gm_s[:n_batch, :, :])
            style_loss *= style_weight

            total_loss = content_loss + style_loss
            total_loss.backward()
            optimizer.step()

            agg_content_loss += content_loss.item()
            agg_style_loss += style_loss.item()

            if (batch_id + 1) % log_interval == 0:
                mesg = "{}\tEpoch {}:\t[{}/{}]\tcontent: {:.6f}\tstyle: {:.6f}\ttotal: {:.6f}".format(
                    time.ctime(), epoch + 1, count, len(train_dataset),
                                  agg_content_loss / (batch_id + 1),
                                  agg_style_loss / (batch_id + 1),
                                  (agg_content_loss + agg_style_loss) / (batch_id + 1)
                )
                print(mesg)

            if checkpoint_dir is not None and (batch_id + 1) % checkpoint_interval == 0:
                transformer.eval().cpu()
                ckpt_model_filename = "ckpt_epoch_" + str(epoch) + "_batch_id_" + str(batch_id + 1) + ".pth"
                print(str(epoch), "th checkpoint is saved!")
                ckpt_model_path = os.path.join(checkpoint_dir, ckpt_model_filename)
                torch.save({
                'epoch': epoch,
                'model_state_dict': transformer.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': total_loss
                }, ckpt_model_path)

                transformer.to(device).train()

# %%
if running_option == "test":
    content_image = load_image("/content/gdrive/My Drive/Colab_Notebooks/data/sanok_test.png", scale=2) #FIXME
    content_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.mul(255))
    ])
    content_image = content_transform(content_image)
    content_image = content_image.unsqueeze(0).to(device)

    with torch.no_grad():
        style_model = TransformerNet()
        
        ckpt_model_path = os.path.join(checkpoint_dir, "ckpt_epoch_63_batch_id_500.pth") #FIXME
        checkpoint = torch.load(ckpt_model_path, map_location=device)
        
        # remove saved deprecated running_* keys in InstanceNorm from the checkpoint
        for k in list(checkpoint.keys()):
            if re.search(r'in\d+\.running_(mean|var)$', k):
                del checkpoint[k]
        
        style_model.load_state_dict(checkpoint['model_state_dict'])
        style_model.to(device)
        
        output = style_model(content_image).cpu()
        
    save_image("/content/gdrive/My Drive/Colab_Notebooks/data/sanok_result.png", output[0]) #FIXME

# %%
if running_option == "test_video":
    
    with torch.no_grad():
        style_model = TransformerNet()

        ckpt_model_path = os.path.join(checkpoint_dir, "ckpt_epoch_63_batch_id_500.pth") #FIXME
        checkpoint = torch.load(ckpt_model_path, map_location=device)

        # remove saved deprecated running_* keys in InstanceNorm from the checkpoint
        for k in list(checkpoint.keys()):
            if re.search(r'in\d+\.running_(mean|var)$', k):
                del checkpoint[k]

        style_model.load_state_dict(checkpoint['model_state_dict'])
        style_model.to(device)

        cap = cv2.VideoCapture("/content/gdrive/My Drive/Colab_Notebooks/data/mirama_demo.mp4") #FIXME

        frame_cnt = 0
        
        fourcc = cv2.VideoWriter_fourcc(*'XVID') 
        out = cv2.VideoWriter('/content/gdrive/My Drive/Colab_Notebooks/data/mirama_demo_result.avi', fourcc, 60.0, (1920,1080)) #FIXME

        
        while(cap.isOpened()):
            ret, frame = cap.read()
            
            try:
              frame = frame[:,:,::-1] - np.zeros_like(frame)
            except:
              break
              
            print(frame_cnt, "th frame is loaded!")

            content_image = frame
            content_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Lambda(lambda x: x.mul(255))
            ])
            content_image = content_transform(content_image)
            content_image = content_image.unsqueeze(0).to(device)

            output = style_model(content_image).cpu()
            #save_image("/content/gdrive/My Drive/Colab_Notebooks/data/vikendi_video_result/" + str(frame_cnt) +".png", output[0]) #FIXME
            out.write(post_process_image(output[0]))
            frame_cnt += 1
            

        cap.release()
        out.release()
        cv2.destroyAllWindows()
# Out:
# 0 th frame is loaded!
# 1 th frame is loaded!
# 2 th frame is loaded!
# 3 th frame is loaded!
# 4 th frame is loaded!
# 5 th frame is loaded!
# 6 th frame is loaded!
# 7 th frame is loaded!
# 8 th frame is loaded!
# 9 th frame is loaded!
# 10 th frame is loaded!
# 11 th frame is loaded!
# 12 th frame is loaded!
# 13 th frame is loaded!
# 14 th frame is loaded!
# 15 th frame is loaded!
# 16 th frame is loaded!
# 17 th frame is loaded!
# 18 th frame is loaded!
# 19 th frame is loaded!
# 20 th frame is loaded!
# 21 th frame is loaded!
# 22 th frame is loaded!
# 23 th frame is loaded!
# 24 th frame is loaded!
# 25 th frame is loaded!
# 26 th frame is loaded!
# 27 th frame is loaded!
# 28 th frame is loaded!
# 29 th frame is loaded!
# 30 th frame is loaded!
# 31 th frame is loaded!
# 32 th frame is loaded!
# 33 th frame is loaded!
# 34 th frame is loaded!
# 35 th frame is loaded!
# 36 th frame is loaded!
# 37 th frame is loaded!
# 38 th frame is loaded!
# 39 th frame is loaded!
# 40 th frame is loaded!
# 41 th frame is loaded!
# 42 th frame is loaded!
# 43 th frame is loaded!
# 44 th frame is loaded!
# 45 th frame is loaded!
# 46 th frame is loaded!
# 47 th frame is loaded!
# 48 th frame is loaded!
# 49 th frame is loaded!
# 50 th frame is loaded!
# 51 th frame is loaded!
# 52 th frame is loaded!
# 53 th frame is loaded!
# 54 th frame is loaded!
# 55 th frame is loaded!
# 56 th frame is loaded!
# 57 th frame is loaded!
# 58 th frame is loaded!
# 59 th frame is loaded!
# 60 th frame is loaded!
# 61 th frame is loaded!
# 62 th frame is loaded!
# 63 th frame is loaded!
# 64 th frame is loaded!
# 65 th frame is loaded!
# 66 th frame is loaded!
# 67 th frame is loaded!
# 68 th frame is loaded!
# 69 th frame is loaded!
# 70 th frame is loaded!
# 71 th frame is loaded!
# 72 th frame is loaded!
# 73 th frame is loaded!
# 74 th frame is loaded!
# 75 th frame is loaded!
# 76 th frame is loaded!
# 77 th frame is loaded!
# 78 th frame is loaded!
# 79 th frame is loaded!
# 80 th frame is loaded!
# 81 th frame is loaded!
# 82 th frame is loaded!
# 83 th frame is loaded!
# 84 th frame is loaded!
# 85 th frame is loaded!
# 86 th frame is loaded!
# 87 th frame is loaded!
# 88 th frame is loaded!
# 89 th frame is loaded!
# 90 th frame is loaded!
# 91 th frame is loaded!
# 92 th frame is loaded!
# 93 th frame is loaded!
# 94 th frame is loaded!
# 95 th frame is loaded!
# 96 th frame is loaded!
# 97 th frame is loaded!
# 98 th frame is loaded!
# 99 th frame is loaded!
# 100 th frame is loaded!
# 101 th frame is loaded!
# 102 th frame is loaded!
# 103 th frame is loaded!
# 104 th frame is loaded!
# 105 th frame is loaded!
# 106 th frame is loaded!
# 107 th frame is loaded!
# 108 th frame is loaded!
# 109 th frame is loaded!
# 110 th frame is loaded!
# 111 th frame is loaded!
# 112 th frame is loaded!
# 113 th frame is loaded!
# 114 th frame is loaded!
# 115 th frame is loaded!
# 116 th frame is loaded!
# 117 th frame is loaded!
# 118 th frame is loaded!
# 119 th frame is loaded!
# 120 th frame is loaded!
# 121 th frame is loaded!
# 122 th frame is loaded!
# 123 th frame is loaded!
# 124 th frame is loaded!
# 125 th frame is loaded!
# 126 th frame is loaded!
# 127 th frame is loaded!
# 128 th frame is loaded!
# 129 th frame is loaded!
# 130 th frame is loaded!
# 131 th frame is loaded!
# 132 th frame is loaded!
# 133 th frame is loaded!
# 134 th frame is loaded!
# 135 th frame is loaded!
# 136 th frame is loaded!
# 137 th frame is loaded!
# 138 th frame is loaded!
# 139 th frame is loaded!
# 140 th frame is loaded!
# 141 th frame is loaded!
# 142 th frame is loaded!
# 143 th frame is loaded!
# 144 th frame is loaded!
# 145 th frame is loaded!
# 146 th frame is loaded!
# 147 th frame is loaded!
# 148 th frame is loaded!
# 149 th frame is loaded!
# 150 th frame is loaded!
# 151 th frame is loaded!
# 152 th frame is loaded!
# 153 th frame is loaded!
# 154 th frame is loaded!
# 155 th frame is loaded!
# 156 th frame is loaded!
# 157 th frame is loaded!
# 158 th frame is loaded!
# 159 th frame is loaded!
# 160 th frame is loaded!
# 161 th frame is loaded!
# 162 th frame is loaded!
# 163 th frame is loaded!
# 164 th frame is loaded!
# 165 th frame is loaded!
# 166 th frame is loaded!
# 167 th frame is loaded!
# 168 th frame is loaded!
# 169 th frame is loaded!
# 170 th frame is loaded!
# 171 th frame is loaded!
# 172 th frame is loaded!
# 173 th frame is loaded!
# 174 th frame is loaded!
# 175 th frame is loaded!
# 176 th frame is loaded!
# 177 th frame is loaded!
# 178 th frame is loaded!
# 179 th frame is loaded!
# 180 th frame is loaded!
# 181 th frame is loaded!
# 182 th frame is loaded!
# 183 th frame is loaded!
# 184 th frame is loaded!
# 185 th frame is loaded!
# 186 th frame is loaded!
# 187 th frame is loaded!
# 188 th frame is loaded!
# 189 th frame is loaded!
# 190 th frame is loaded!
# 191 th frame is loaded!
# 192 th frame is loaded!
# 193 th frame is loaded!
# 194 th frame is loaded!
# 195 th frame is loaded!
# 196 th frame is loaded!
# 197 th frame is loaded!
# 198 th frame is loaded!
# 199 th frame is loaded!
# 200 th frame is loaded!
# 201 th frame is loaded!
# 202 th frame is loaded!
# 203 th frame is loaded!
# 204 th frame is loaded!
# 205 th frame is loaded!
# 206 th frame is loaded!
# 207 th frame is loaded!
# 208 th frame is loaded!
# 209 th frame is loaded!
# 210 th frame is loaded!
# 211 th frame is loaded!
# 212 th frame is loaded!
# 213 th frame is loaded!
# 214 th frame is loaded!
# 215 th frame is loaded!
# 216 th frame is loaded!
# 217 th frame is loaded!
# 218 th frame is loaded!
# 219 th frame is loaded!
# 220 th frame is loaded!
# 221 th frame is loaded!
# 222 th frame is loaded!
# 223 th frame is loaded!
# 224 th frame is loaded!
# 225 th frame is loaded!
# 226 th frame is loaded!
# 227 th frame is loaded!
# 228 th frame is loaded!
# 229 th frame is loaded!
# 230 th frame is loaded!
# 231 th frame is loaded!
# 232 th frame is loaded!
# 233 th frame is loaded!
# 234 th frame is loaded!
# 235 th frame is loaded!
# 236 th frame is loaded!
# 237 th frame is loaded!
# 238 th frame is loaded!
# 239 th frame is loaded!
# 240 th frame is loaded!
# 241 th frame is loaded!
# 242 th frame is loaded!
# 243 th frame is loaded!
# 244 th frame is loaded!
# 245 th frame is loaded!
# 246 th frame is loaded!
# 247 th frame is loaded!
# 248 th frame is loaded!
# 249 th frame is loaded!
# 250 th frame is loaded!
# 251 th frame is loaded!
# 252 th frame is loaded!
# 253 th frame is loaded!
# 254 th frame is loaded!
# 255 th frame is loaded!
# 256 th frame is loaded!
# 257 th frame is loaded!
# 258 th frame is loaded!
# 259 th frame is loaded!
# 260 th frame is loaded!
# 261 th frame is loaded!
# 262 th frame is loaded!
# 263 th frame is loaded!
# 264 th frame is loaded!
# 265 th frame is loaded!
# 266 th frame is loaded!
# 267 th frame is loaded!
# 268 th frame is loaded!
# 269 th frame is loaded!
# 270 th frame is loaded!
# 271 th frame is loaded!
# 272 th frame is loaded!
# 273 th frame is loaded!
# 274 th frame is loaded!
# 275 th frame is loaded!
# 276 th frame is loaded!
# 277 th frame is loaded!
# 278 th frame is loaded!
# 279 th frame is loaded!
# 280 th frame is loaded!
# 281 th frame is loaded!
# 282 th frame is loaded!
# 283 th frame is loaded!
# 284 th frame is loaded!
# 285 th frame is loaded!
# 286 th frame is loaded!
# 287 th frame is loaded!
# 288 th frame is loaded!
# 289 th frame is loaded!
# 290 th frame is loaded!
# 291 th frame is loaded!
# 292 th frame is loaded!
# 293 th frame is loaded!
# 294 th frame is loaded!
# 295 th frame is loaded!
# 296 th frame is loaded!
# 297 th frame is loaded!
# 298 th frame is loaded!
# 299 th frame is loaded!
# 300 th frame is loaded!
# 301 th frame is loaded!
# 302 th frame is loaded!
# 303 th frame is loaded!
# 304 th frame is loaded!
# 305 th frame is loaded!
# 306 th frame is loaded!
# 307 th frame is loaded!
# 308 th frame is loaded!
# 309 th frame is loaded!
# 310 th frame is loaded!
# 311 th frame is loaded!
# 312 th frame is loaded!
# 313 th frame is loaded!
# 314 th frame is loaded!
# 315 th frame is loaded!
# 316 th frame is loaded!
# 317 th frame is loaded!
# 318 th frame is loaded!
# 319 th frame is loaded!
# 320 th frame is loaded!
# 321 th frame is loaded!
# 322 th frame is loaded!
# 323 th frame is loaded!
# 324 th frame is loaded!
# 325 th frame is loaded!
# 326 th frame is loaded!
# 327 th frame is loaded!
# 328 th frame is loaded!
# 329 th frame is loaded!
# 330 th frame is loaded!
# 331 th frame is loaded!
# 332 th frame is loaded!
# 333 th frame is loaded!
# 334 th frame is loaded!
# 335 th frame is loaded!
# 336 th frame is loaded!
# 337 th frame is loaded!
# 338 th frame is loaded!
# 339 th frame is loaded!
# 340 th frame is loaded!
# 341 th frame is loaded!
# 342 th frame is loaded!
# 343 th frame is loaded!
# 344 th frame is loaded!
# 345 th frame is loaded!
# 346 th frame is loaded!
# 347 th frame is loaded!
# 348 th frame is loaded!
# 349 th frame is loaded!
# 350 th frame is loaded!
# 351 th frame is loaded!
# 352 th frame is loaded!
# 353 th frame is loaded!
# 354 th frame is loaded!
# 355 th frame is loaded!
# 356 th frame is loaded!
# 357 th frame is loaded!
# 358 th frame is loaded!
# 359 th frame is loaded!
# 360 th frame is loaded!
# 361 th frame is loaded!
# 362 th frame is loaded!
# 363 th frame is loaded!
# 364 th frame is loaded!
# 365 th frame is loaded!
# 366 th frame is loaded!
# 367 th frame is loaded!
# 368 th frame is loaded!
# 369 th frame is loaded!
# 370 th frame is loaded!
# 371 th frame is loaded!
# 372 th frame is loaded!
# 373 th frame is loaded!
# 374 th frame is loaded!
# 375 th frame is loaded!
# 376 th frame is loaded!
# 377 th frame is loaded!
# 378 th frame is loaded!
# 379 th frame is loaded!
# 380 th frame is loaded!
# 381 th frame is loaded!
# 382 th frame is loaded!
# 383 th frame is loaded!
# 384 th frame is loaded!
# 385 th frame is loaded!
# 386 th frame is loaded!
# 387 th frame is loaded!
# 388 th frame is loaded!
# 389 th frame is loaded!
# 390 th frame is loaded!
# 391 th frame is loaded!
# 392 th frame is loaded!
# 393 th frame is loaded!
# 394 th frame is loaded!
# 395 th frame is loaded!
# 396 th frame is loaded!
# 397 th frame is loaded!
# 398 th frame is loaded!
# 399 th frame is loaded!
# 400 th frame is loaded!
# 401 th frame is loaded!
# 402 th frame is loaded!
# 403 th frame is loaded!
# 404 th frame is loaded!
# 405 th frame is loaded!
# 406 th frame is loaded!
# 407 th frame is loaded!
# 408 th frame is loaded!
# 409 th frame is loaded!
# 410 th frame is loaded!
# 411 th frame is loaded!
# 412 th frame is loaded!
# 413 th frame is loaded!
# 414 th frame is loaded!
# 415 th frame is loaded!
# 416 th frame is loaded!
# 417 th frame is loaded!
# 418 th frame is loaded!
# 419 th frame is loaded!
# 420 th frame is loaded!
# 421 th frame is loaded!
# 422 th frame is loaded!
# 423 th frame is loaded!
# 424 th frame is loaded!
# 425 th frame is loaded!
# 426 th frame is loaded!
# 427 th frame is loaded!
# 428 th frame is loaded!
# 429 th frame is loaded!
# 430 th frame is loaded!
# 431 th frame is loaded!
# 432 th frame is loaded!
# 433 th frame is loaded!
# 434 th frame is loaded!
# 435 th frame is loaded!
# 436 th frame is loaded!
# 437 th frame is loaded!
# 438 th frame is loaded!
# 439 th frame is loaded!
# 440 th frame is loaded!
# 441 th frame is loaded!
# 442 th frame is loaded!
# 443 th frame is loaded!
# 444 th frame is loaded!
# 445 th frame is loaded!
# 446 th frame is loaded!
# 447 th frame is loaded!
# 448 th frame is loaded!
# 449 th frame is loaded!
# 450 th frame is loaded!
# 451 th frame is loaded!
# 452 th frame is loaded!
# 453 th frame is loaded!
# 454 th frame is loaded!
# 455 th frame is loaded!
# 456 th frame is loaded!
# 457 th frame is loaded!
# 458 th frame is loaded!
# 459 th frame is loaded!
# 460 th frame is loaded!
# 461 th frame is loaded!
# 462 th frame is loaded!
# 463 th frame is loaded!
# 464 th frame is loaded!
# 465 th frame is loaded!
# 466 th frame is loaded!
# 467 th frame is loaded!
# 468 th frame is loaded!
# 469 th frame is loaded!
# 470 th frame is loaded!
# 471 th frame is loaded!
# 472 th frame is loaded!
# 473 th frame is loaded!
# 474 th frame is loaded!
# 475 th frame is loaded!
# 476 th frame is loaded!
# 477 th frame is loaded!
# 478 th frame is loaded!
# 479 th frame is loaded!
# 480 th frame is loaded!
# 481 th frame is loaded!
# 482 th frame is loaded!
# 483 th frame is loaded!
# 484 th frame is loaded!
# 485 th frame is loaded!
# 486 th frame is loaded!
# 487 th frame is loaded!
# 488 th frame is loaded!
# 489 th frame is loaded!
# 490 th frame is loaded!
# 491 th frame is loaded!
# 492 th frame is loaded!
# 493 th frame is loaded!
# 494 th frame is loaded!
# 495 th frame is loaded!
# 496 th frame is loaded!
# 497 th frame is loaded!
# 498 th frame is loaded!
# 499 th frame is loaded!
# 500 th frame is loaded!
# 501 th frame is loaded!
# 502 th frame is loaded!
# 503 th frame is loaded!
# 504 th frame is loaded!
# 505 th frame is loaded!
# 506 th frame is loaded!
# 507 th frame is loaded!
# 508 th frame is loaded!
# 509 th frame is loaded!
# 510 th frame is loaded!
# 511 th frame is loaded!
# 512 th frame is loaded!
# 513 th frame is loaded!
# 514 th frame is loaded!
# 515 th frame is loaded!
# 516 th frame is loaded!
# 517 th frame is loaded!
# 518 th frame is loaded!
# 519 th frame is loaded!
# 520 th frame is loaded!
# 521 th frame is loaded!
# 522 th frame is loaded!
# 523 th frame is loaded!
# 524 th frame is loaded!
# 525 th frame is loaded!
# 526 th frame is loaded!
# 527 th frame is loaded!
# 528 th frame is loaded!
# 529 th frame is loaded!
# 530 th frame is loaded!
# 531 th frame is loaded!
# 532 th frame is loaded!
# 533 th frame is loaded!
# 534 th frame is loaded!
# 535 th frame is loaded!
# 536 th frame is loaded!
# 537 th frame is loaded!
# 538 th frame is loaded!
# 539 th frame is loaded!
# 540 th frame is loaded!
# 541 th frame is loaded!
# 542 th frame is loaded!
# 543 th frame is loaded!
# 544 th frame is loaded!
# 545 th frame is loaded!
# 546 th frame is loaded!
# 547 th frame is loaded!
# 548 th frame is loaded!
# 549 th frame is loaded!
# 550 th frame is loaded!
# 551 th frame is loaded!
# 552 th frame is loaded!
# 553 th frame is loaded!
# 554 th frame is loaded!
# 555 th frame is loaded!
# 556 th frame is loaded!
# 557 th frame is loaded!
# 558 th frame is loaded!
# 559 th frame is loaded!
# 560 th frame is loaded!
# 561 th frame is loaded!
# 562 th frame is loaded!
# 563 th frame is loaded!
# 564 th frame is loaded!
# 565 th frame is loaded!
# 566 th frame is loaded!
# 567 th frame is loaded!
# 568 th frame is loaded!
# 569 th frame is loaded!
